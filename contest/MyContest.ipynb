# %% [markdown]
# # Постановка задачи

# %% [markdown]
# На сегодняшний день машинное обучение решает абсолютно разные задачи практически во всех областях нашей жизни. Платформа DataDriven организовывает контесты по машинному обучению для решения реальных задач общественных и некоммерческих организаций по всему миру, применяя результаты победителей. Данный проект призван решить проблемы водоснабжения в стране Танзания в Восточной Африке. Вода в Танзании добывается с помощью водокачек, и они часто выходят из строя, оставляя поселения без воды. Задача участников - по параметрам и статусу некоторого множества водокачек определить возможность поломки и необходимость обслуживания других водокачек.
#
# В данной задаче мы не только сделаем предсказания о состоянии водокачек, но и оценим, как качество данных влияет на предсказание.
#
# Ссылка на контест: https://www.drivendata.org/competitions/7/pump-it-up-data-mining-the-water-table/

# %% [markdown]
# # Описание метода

# %% [markdown]
# Задача будет решаться с помощью градиентного бустинга - будем использовать одноимённый метод GradientBoosting из пакета sklearn.

# %% [markdown]
# ## Практическая суть задачи

# %% [markdown]
# Пусть у нас существует некоторый набор пар {(𝑥𝑖,𝑦𝑖)}, i=1..n, где x - это признак, y - целевая переменная. Задача сводится к тому, чтобы восстановить функцию y=F(x) - функцию, минимизирующую функцию потерь L(x, F(x))

# %% [markdown]
# ## Градиентный бустинг

# %% [markdown]
# Метод градиентного бустинга позволяет построить итоговую модель F(x) как взвешенную функцию слабых моделей Fm(x), m = 1..M. К каждой предыдущей сумме Fm-1(x) добавляется частная производная от функции L(x, Fm(x)) по Fm(x) со знаком минус - для минимизации потерь. Назовём эту производную hm(x). Необходимо также, чтобы функция L(x, Fm(x)) была дифференцируема в достаточно большой области.

# %%
import pandas as pd
import numpy as np
import math
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# Для работы будем использовать библиотеку Pandas. Выведем следующие данные:
# TrainingX - множество признаков - набор данных о характеристиках водокачек
# TrainingY - множество целевых переменных - набор данных о состоянии водокачек
# TestX - множество признаков - набор данных о характеристиках водокачек, по которым требуется совершить предсказание.

# %%
TrainingX = pd.read_csv('./contest/trainingsetvalues.csv', sep=',')
TrainingY = pd.read_csv('./contest/trainingsetlabels.csv', sep=',')
TestX = pd.read_csv('./contest/testsetvalues.csv', sep=',')

# %% [markdown]
# Посмотрим, что представляют из себя данные о характеристиках водокачек:

# %%
print(type(TrainingX))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
TrainingX.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %% [markdown]
# # Пояснения к данным
#
# Перечень столбцов с расшифровкой:
# amount_tsh - Общий статический напор (количество воды, доступное для водокачки)
# date_recorded - Дата ввода данных
# funder - Кто финансировал колодец
# gps_height - Глубина скважины
# installer - Организация, вырывшая скважину
# longitude - GPS-координата
# latitude - GPS-координата
# wpt_name - Название водоема, если он есть
# num_private -
# basin - Географическое расположение водоёма
# subvillage - Географическое положение населённого пункта
# region - Географическое положение региона
# region_code - Код региона
# district_code - Код района
# lga - Географическое положение
# ward - Географическое положение
# population - Население вокруг скважины
# public_meeting - Верно/Ложно
# recorded_by - Групповой ввод этой строки данных
# scheme_management - Кто управляет водокачкой
# scheme_name - Кто управляет водокачкой
# permit - Разрешен ли водозабор
# construction_year - Год постройки водозабора
# extraction_type - Тип добычи воды, которую использует водонапорная точка
# extraction_type_group - Подвид добычи воды, которую использует водонапорная точка
# extraction_type_class - Класс добычи воды, которую использует водонапорная точка
# management - Как управляется водокачка
# management_group - Как управляется водокачка
# payment - Сколько стоит вода
# payment_type - Сколько стоит вода
# water_quality - Качество воды
# quality_group - Качество воды
# quantity - Количество воды
# quantity_group - Количество воды
# source - Источник воды
# source_type - Источник воды
# source_class - Источник воды
# waterpoint_type - Вид водоема
# waterpoint_type_group - Вид водоема

# %% [markdown]
# # Распределение данных по параметрам строковых типов
# Чтобы включить в модель такие признаки, необходимо, чтобы было достаточно данных по каждому из них, и чтобы данные были достаточно равномерно распределены по ним. Для начала посмотрим, какие типы столбцов и в каком количестве у нас имеются:

# %%
TrainingX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
#  14  district_code          59400 non-null  int64
#  15  lga                    59400 non-null  object
#  16  ward                   59400 non-null  object
#  17  population             59400 non-null  int64
#  18  public_meeting         56066 non-null  object
#  19  recorded_by            59400 non-null  object
#  20  scheme_management      55523 non-null  object
#  21  scheme_name            31234 non-null  object
#  22  permit                 56344 non-null  object
#  23  construction_year      59400 non-null  int64
#  24  extraction_type        59400 non-null  object
#  25  extraction_type_group  59400 non-null  object
#  26  extraction_type_class  59400 non-null  object
#  27  management             59400 non-null  object
#  28  management_group       59400 non-null  object
#  29  payment                59400 non-null  object
#  30  payment_type           59400 non-null  object
#  31  water_quality          59400 non-null  object
#  32  quality_group          59400 non-null  object
#  33  quantity               59400 non-null  object
#  34  quantity_group         59400 non-null  object
#  35  source                 59400 non-null  object
#  36  source_type            59400 non-null  object
#  37  source_class           59400 non-null  object
#  38  waterpoint_type        59400 non-null  object
#  39  waterpoint_type_group  59400 non-null  object
# dtypes: float64(3), int64(7), object(30)
# memory usage: 11.3+ MB

# %% [markdown]
# Как мы видим,  строковых значений в таблице 30, целочисленных - 7, вещественных - 3. Посмотрим на таблицу, содержащую только строковые типы данных:

# %%
TrainingX.select_dtypes(include=['object'])
# Out:
#       date_recorded           funder     installer              wpt_name  \
# 0        2011-03-14            Roman         Roman                  none
# 1        2013-03-06          Grumeti       GRUMETI              Zahanati
# 2        2013-02-25     Lottery Club  World vision           Kwa Mahundi
# 3        2013-01-28           Unicef        UNICEF  Zahanati Ya Nanyumbu
# 4        2011-07-13      Action In A       Artisan               Shuleni
# ...             ...              ...           ...                   ...
# 59395    2013-05-03  Germany Republi           CES   Area Three Namba 27
# 59396    2011-05-07      Cefa-njombe          Cefa     Kwa Yahona Kuvala
# 59397    2011-04-11              NaN           NaN               Mashine
# 59398    2011-03-08            Malec          Musa                Mshoro
# 59399    2011-03-23       World Bank         World       Kwa Mzee Lugawa
#
#                          basin    subvillage       region             lga  \
# 0                   Lake Nyasa      Mnyusi B       Iringa          Ludewa
# 1                Lake Victoria       Nyamara         Mara       Serengeti
# 2                      Pangani       Majengo      Manyara       Simanjiro
# 3      Ruvuma / Southern Coast    Mahakamani       Mtwara        Nanyumbu
# 4                Lake Victoria    Kyanyamisa       Kagera         Karagwe
# ...                        ...           ...          ...             ...
# 59395                  Pangani      Kiduruni  Kilimanjaro             Hai
# 59396                   Rufiji      Igumbilo       Iringa          Njombe
# 59397                   Rufiji     Madungulu        Mbeya         Mbarali
# 59398                   Rufiji        Mwinyi       Dodoma        Chamwino
# 59399              Wami / Ruvu  Kikatanyemba     Morogoro  Morogoro Rural
#
#                    ward public_meeting  ... payment_type water_quality  \
# 0              Mundindi           True  ...     annually          soft
# 1                 Natta            NaN  ...    never pay          soft
# 2               Ngorika           True  ...   per bucket          soft
# 3              Nanyumbu           True  ...    never pay          soft
# 4            Nyakasimbi           True  ...    never pay          soft
# ...                 ...            ...  ...          ...           ...
# 59395  Masama Magharibi           True  ...   per bucket          soft
# 59396            Ikondo           True  ...     annually          soft
# 59397           Chimala           True  ...      monthly      fluoride
# 59398      Mvumi Makulu           True  ...    never pay          soft
# 59399        Ngerengere           True  ...   on failure         salty
#
#       quality_group      quantity quantity_group                source  \
# 0              good        enough         enough                spring
# 1              good  insufficient   insufficient  rainwater harvesting
# 2              good        enough         enough                   dam
# 3              good           dry            dry           machine dbh
# 4              good      seasonal       seasonal  rainwater harvesting
# ...             ...           ...            ...                   ...
# 59395          good        enough         enough                spring
# 59396          good        enough         enough                 river
# 59397      fluoride        enough         enough           machine dbh
# 59398          good  insufficient   insufficient          shallow well
# 59399         salty        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# 0                    spring  groundwater           communal standpipe
# 1      rainwater harvesting      surface           communal standpipe
# 2                       dam      surface  communal standpipe multiple
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 59395                spring  groundwater           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#       waterpoint_type_group
# 0        communal standpipe
# 1        communal standpipe
# 2        communal standpipe
# 3        communal standpipe
# 4        communal standpipe
# ...                     ...
# 59395    communal standpipe
# 59396    communal standpipe
# 59397             hand pump
# 59398             hand pump
# 59399             hand pump
#
# [59400 rows x 30 columns]

# %% [markdown]
# ## Практическая оценка качества данных
# Для начала попробуем оценить качество данных, построив модель напрямую. Оценим точность предсказания, разделив данные на две части: на одной обучим модель, по второй оценим точность.

# %% [markdown]
# Делим данные на два датафрейма:

# %%
TrainX1 = TrainingX[:29700]
TrainY1 = TrainingY[:29700]
TrainX2 = TrainingX[29700:]

# %% [markdown]
# Создаём объект модели:

# %%
model = GradientBoostingClassifier(
        n_estimators=500,
        max_depth=5,
        #subsample=0.5,
        max_features="auto"
        # random_state=seed
    )

# %% [markdown]
# Включаем в выборку все столбцы, приводимые к float напрямую, и приводим типы данных:

# %%
TrainX1.dtypes == object
# Out:
# id                       False
# amount_tsh               False
# date_recorded             True
# funder                    True
# gps_height               False
# installer                 True
# longitude                False
# latitude                 False
# wpt_name                  True
# num_private              False
# basin                     True
# subvillage                True
# region                    True
# region_code              False
# district_code            False
# lga                       True
# ward                      True
# population               False
# public_meeting            True
# recorded_by               True
# scheme_management         True
# scheme_name               True
# permit                    True
# construction_year        False
# extraction_type           True
# extraction_type_group     True
# extraction_type_class     True
# management                True
# management_group          True
# payment                   True
# payment_type              True
# water_quality             True
# quality_group             True
# quantity                  True
# quantity_group            True
# source                    True
# source_type               True
# source_class              True
# waterpoint_type           True
# waterpoint_type_group     True
# dtype: bool

# %%
# Out:
# id                       False
# amount_tsh               False
# date_recorded            False
# funder                   False
# gps_height               False
# installer                False
# longitude                False
# latitude                 False
# wpt_name                 False
# num_private              False
# basin                    False
# subvillage               False
# region                   False
# region_code              False
# district_code            False
# lga                      False
# ward                     False
# population               False
# public_meeting           False
# recorded_by              False
# scheme_management        False
# scheme_name              False
# permit                   False
# construction_year        False
# extraction_type          False
# extraction_type_group    False
# extraction_type_class    False
# management               False
# management_group         False
# payment                  False
# payment_type             False
# water_quality            False
# quality_group            False
# quantity                 False
# quantity_group           False
# source                   False
# source_type              False
# source_class             False
# waterpoint_type          False
# waterpoint_type_group    False
# dtype: bool

# %%
ctrainX = TrainX1[['id',
 'amount_tsh',
 'date_recorded',
 'funder',
 'gps_height',
 'installer',
 'longitude',
 'latitude',
 'wpt_name',
 'num_private',
 'basin',
 'subvillage',
 'region',
 'region_code',
 'district_code',
 'lga',
 'ward',
 'population',
 'public_meeting',
 'recorded_by',
 'scheme_management',
 'scheme_name',
 'permit',
 'construction_year',
 'extraction_type',
 'extraction_type_group',
 'extraction_type_class',
 'management',
 'management_group',
 'payment',
 'payment_type',
 'water_quality',
 'quality_group',
 'quantity',
 'quantity_group',
 'source',
 'source_type',
 'source_class',
 'waterpoint_type',
 'waterpoint_type_group']]
#ctrainX = ctrainX.values()
ctrainX = ctrainX.astype(float)
ctrain
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\C523~1\AppData\Local\Temp/ipykernel_14836/3336905011.py in <module>
#      39  'waterpoint_type_group']]
#      40 #ctrainX = ctrainX.values()
# ---> 41 ctrainX = ctrainX.astype(float)
#      42 ctrain
#
# c:\python3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# c:\python3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# c:\python3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# c:\python3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# c:\python3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\python3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# c:\python3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1093     if arr.ndim > 1:
#    1094         flat = arr.ravel()
# -> 1095         result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1096         # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1097         # attribute "reshape"
#
# c:\python3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Roman'

# %% [markdown]
# ## Оптимизация данных
# Для начала нам надо определить, есть ли записи об одних и тех же водокачках и насколько различаются данные по ним. Уникальными значениями для каждой из водокачек являются их GPS-координаты. Оценим, как много в таблице уникальных водокачек по координатам:

# %%
len(TrainingX['latitude'].unique())
# Out:
# 57517

# %%
len(TrainingX['longitude'].unique())
# Out:
# 57516

# %%
Train = TrainingX.loc[TrainingX['longitude'] != 0]
#TrainingX.groupby('latitude')['longitude']

Train[Train.duplicated(subset='longitude',keep=False)][Train.duplicated(subset='latitude',keep=False)]
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#           id  amount_tsh date_recorded    funder  gps_height installer  \
# 1317   62247      2000.0    2011-07-19         P        1262         P
# 1901   38641       100.0    2013-03-16       NaN          65       NaN
# 2287   42469         0.0    2011-03-24  Nethalan         583       RWE
# 2401   58328         0.0    2011-07-20         H           0         H
# 2457   73178         0.0    2011-07-20         L        1195         L
# ...      ...         ...           ...       ...         ...       ...
# 57390  60604        50.0    2013-03-15       NaN          62       NaN
# 57423  38295         0.0    2011-03-27  W.D & I.         557       RWE
# 57824  29698      1000.0    2011-03-24  Nethalan         621       RWE
# 58190  58212         0.0    2011-07-15         H           0         H
# 58561  39242         0.0    2011-07-15         H           0         H
#
#        longitude  latitude                      wpt_name  num_private  ...  \
# 1317   33.015597 -2.487085            Kwa Chongo Kideshe            0  ...
# 1901   39.090880 -6.981830  Kwa Bwana Shamba Wa Manispaa            0  ...
# 2287   37.339811 -7.065373                       Ofisini            0  ...
# 2401   32.988560 -2.489378                   Kwa Kaombwe            0  ...
# 2457   32.956523 -2.494353             Kwa Julias Mabula            0  ...
# ...          ...       ...                           ...          ...  ...
# 57390  39.096499 -6.980216                    Kwa Semkwa            0  ...
# 57423  37.540901 -6.959749            Kwa Nasoro Kinenge            0  ...
# 57824  37.375717 -7.056372                     Kwa Yusta            0  ...
# 58190  32.978062 -2.515321                 Kwa Buswelu B            0  ...
# 58561  32.967009 -2.506590                   Kwa Buhyila            0  ...
#
#       payment_type    water_quality quality_group      quantity  \
# 1317       monthly             soft          good        enough
# 1901    per bucket  salty abandoned         salty  insufficient
# 2287     never pay             soft          good        enough
# 2401     never pay             soft          good  insufficient
# 2457     never pay            salty         salty        enough
# ...            ...              ...           ...           ...
# 57390   per bucket  salty abandoned         salty        enough
# 57423    never pay             soft          good        enough
# 57824      monthly            salty         salty  insufficient
# 58190      monthly             soft          good        enough
# 58561   on failure             soft          good  insufficient
#
#        quantity_group        source   source_type  source_class  \
# 1317           enough  shallow well  shallow well   groundwater
# 1901     insufficient   machine dbh      borehole   groundwater
# 2287           enough  shallow well  shallow well   groundwater
# 2401     insufficient  shallow well  shallow well   groundwater
# 2457           enough  shallow well  shallow well   groundwater
# ...               ...           ...           ...           ...
# 57390          enough   machine dbh      borehole   groundwater
# 57423          enough         river    river/lake       surface
# 57824    insufficient  shallow well  shallow well   groundwater
# 58190          enough  shallow well  shallow well   groundwater
# 58561    insufficient  shallow well  shallow well   groundwater
#
#           waterpoint_type waterpoint_type_group
# 1317            hand pump             hand pump
# 1901   communal standpipe    communal standpipe
# 2287            hand pump             hand pump
# 2401            hand pump             hand pump
# 2457                other                 other
# ...                   ...                   ...
# 57390  communal standpipe    communal standpipe
# 57423  communal standpipe    communal standpipe
# 57824           hand pump             hand pump
# 58190           hand pump             hand pump
# 58561           hand pump             hand pump
#
# [138 rows x 40 columns]

# %% [markdown]
# Как мы видим, нашлось 138 водокачек с одинаковыми ненулевыми координатами. Многие из них были профинансированы или построены одними и теми же лицами, что может указывать на то, что это данные об одних и тех же водокачках. Проверим их на совпадение годов ввода в эксплуатацию:

# %%
TrainYEAR = Train[Train.duplicated(subset='longitude',keep=False)][Train.duplicated(subset='latitude',keep=False)]
TrainYEAR[TrainYEAR.duplicated(subset='construction_year', keep = False)]
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#           id  amount_tsh date_recorded    funder  gps_height installer  \
# 1901   38641       100.0    2013-03-16       NaN          65       NaN
# 2287   42469         0.0    2011-03-24  Nethalan         583       RWE
# 2401   58328         0.0    2011-07-20         H           0         H
# 4125   43485         0.0    2011-07-19         P           0         P
# 4488    7415         0.0    2011-07-15         H        1230         H
# ...      ...         ...           ...       ...         ...       ...
# 57390  60604        50.0    2013-03-15       NaN          62       NaN
# 57423  38295         0.0    2011-03-27  W.D & I.         557       RWE
# 57824  29698      1000.0    2011-03-24  Nethalan         621       RWE
# 58190  58212         0.0    2011-07-15         H           0         H
# 58561  39242         0.0    2011-07-15         H           0         H
#
#        longitude  latitude                      wpt_name  num_private  ...  \
# 1901   39.090880 -6.981830  Kwa Bwana Shamba Wa Manispaa            0  ...
# 2287   37.339811 -7.065373                       Ofisini            0  ...
# 2401   32.988560 -2.489378                   Kwa Kaombwe            0  ...
# 4125   33.015597 -2.487085            Kwa Chongo Kideshe            0  ...
# 4488   32.977191 -2.516619                 Kwa Buswelu B            0  ...
# ...          ...       ...                           ...          ...  ...
# 57390  39.096499 -6.980216                    Kwa Semkwa            0  ...
# 57423  37.540901 -6.959749            Kwa Nasoro Kinenge            0  ...
# 57824  37.375717 -7.056372                     Kwa Yusta            0  ...
# 58190  32.978062 -2.515321                 Kwa Buswelu B            0  ...
# 58561  32.967009 -2.506590                   Kwa Buhyila            0  ...
#
#       payment_type    water_quality quality_group      quantity  \
# 1901    per bucket  salty abandoned         salty  insufficient
# 2287     never pay             soft          good        enough
# 2401     never pay             soft          good  insufficient
# 4125       monthly             soft          good        enough
# 4488     never pay             soft          good        enough
# ...            ...              ...           ...           ...
# 57390   per bucket  salty abandoned         salty        enough
# 57423    never pay             soft          good        enough
# 57824      monthly            salty         salty  insufficient
# 58190      monthly             soft          good        enough
# 58561   on failure             soft          good  insufficient
#
#        quantity_group        source   source_type  source_class  \
# 1901     insufficient   machine dbh      borehole   groundwater
# 2287           enough  shallow well  shallow well   groundwater
# 2401     insufficient  shallow well  shallow well   groundwater
# 4125           enough  shallow well  shallow well   groundwater
# 4488           enough  shallow well  shallow well   groundwater
# ...               ...           ...           ...           ...
# 57390          enough   machine dbh      borehole   groundwater
# 57423          enough         river    river/lake       surface
# 57824    insufficient  shallow well  shallow well   groundwater
# 58190          enough  shallow well  shallow well   groundwater
# 58561    insufficient  shallow well  shallow well   groundwater
#
#           waterpoint_type waterpoint_type_group
# 1901   communal standpipe    communal standpipe
# 2287            hand pump             hand pump
# 2401            hand pump             hand pump
# 4125            hand pump             hand pump
# 4488                other                 other
# ...                   ...                   ...
# 57390  communal standpipe    communal standpipe
# 57423  communal standpipe    communal standpipe
# 57824           hand pump             hand pump
# 58190           hand pump             hand pump
# 58561           hand pump             hand pump
#
# [132 rows x 40 columns]

# %% [markdown]
# Посмотрим на повторяющиеся данные:

# %%
TrainYEAR.loc[abs(TrainYEAR['longitude'] - 37.3) < 0.1]
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 2287   42469         0.0    2011-03-24                Nethalan         583
# 7560    8437         0.0    2011-03-23                Nethalan         590
# 8896   45838         0.0    2011-03-17                Nethalan         519
# 10267  49698         0.0    2011-03-17                Nethalan         583
# 13570  21056         0.0    2011-03-24                  Tassaf         512
# 15917  42947      1000.0    2011-03-17                Nethalan         621
# 17442  54643         0.0    2011-03-24                Nethalan         576
# 19866   3559         0.0    2011-03-24                   Abood         486
# 24938  33011         0.0    2011-03-17                  Tassaf         532
# 28701  58162         0.0    2011-03-24                  Tassaf         532
# 29367  28980         0.0    2011-03-17                   Abood         486
# 29640   8451         0.0    2011-03-17                 Germany         496
# 29872  60190         0.0    2011-03-17                  Tassaf         512
# 30760  39206         0.0    2011-03-24                Nethalan         519
# 37766  18406         0.0    2011-03-16                Nethalan         576
# 38604  64847         0.0    2011-03-16                Nethalan         590
# 41601  62326         0.0    2011-03-24                      Rc         609
# 48361  31011         0.0    2011-03-24  Government Of Tanzania         503
# 50232  44391         0.0    2011-03-17  Government Of Tanzania         499
# 50330  36327         0.0    2011-03-24  Government Of Tanzania         499
# 50543  56848         0.0    2011-03-17                      Rc         609
# 50694  42578         0.0    2011-03-23                Nethalan         580
# 50878  12615         0.0    2011-03-17  Government Of Tanzania         503
# 51319  26277         0.0    2011-03-24                 Germany         496
# 51672  14961         0.0    2011-03-16                Nethalan         580
# 57824  29698      1000.0    2011-03-24                Nethalan         621
#
#       installer  longitude  latitude                 wpt_name  num_private  \
# 2287        RWE  37.339811 -7.065373                  Ofisini            0
# 7560        RWE  37.328905 -7.175174          Kwa Said Mlinda            0
# 8896        RWE  37.281357 -7.095131             Kwa Batolome            0
# 10267       RWE  37.339811 -7.065373                  Ofisini            0
# 13570       DWE  37.274352 -7.102004              Kwa Kinenge            0
# 15917       RWE  37.375717 -7.056372                Kwa Yusta            0
# 17442  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka            0
# 19866   Gwaseco  37.236326 -7.093914                Msikitini            0
# 24938       DWE  37.297680 -7.078081            Kwa Gungulima            0
# 28701       DWE  37.297680 -7.078081            Kwa Gungulima            0
# 29367   Gwaseco  37.236326 -7.093914                Msikitini            0
# 29640       RWE  37.252194 -7.103742               Kwa Magera            0
# 29872       DWE  37.274352 -7.102004              Kwa Kinenge            0
# 30760       RWE  37.281357 -7.095131             Kwa Batolome            0
# 37766  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka            0
# 38604       RWE  37.328905 -7.175174          Kwa Said Mlinda            0
# 41601        RC  37.374017 -7.056923                 Kanisani            0
# 48361       DWE  37.269036 -7.104923                 Kwa Beti            0
# 50232       DWE  37.250111 -7.104625               Kwa Magera            0
# 50330       DWE  37.250111 -7.104625               Kwa Magera            0
# 50543        RC  37.374017 -7.056923                 Kanisani            0
# 50694       DWE  37.318911 -7.177155             Kwa Kisuguru            0
# 50878       DWE  37.269036 -7.104923                 Kwa Beti            0
# 51319       RWE  37.252194 -7.103742               Kwa Magera            0
# 51672       DWE  37.318911 -7.177155             Kwa Kisuguru            0
# 57824       RWE  37.375717 -7.056372                Kwa Yusta            0
#
#        ... payment_type water_quality quality_group      quantity  \
# 2287   ...    never pay          soft          good        enough
# 7560   ...    never pay         salty         salty  insufficient
# 8896   ...    never pay          soft          good        enough
# 10267  ...    never pay          soft          good        enough
# 13570  ...    never pay         salty         salty        enough
# 15917  ...      monthly         salty         salty  insufficient
# 17442  ...    never pay          soft          good        enough
# 19866  ...    never pay          soft          good        enough
# 24938  ...    never pay          soft          good        enough
# 28701  ...    never pay          soft          good        enough
# 29367  ...    never pay          soft          good        enough
# 29640  ...    never pay          soft          good  insufficient
# 29872  ...    never pay         salty         salty        enough
# 30760  ...    never pay          soft          good        enough
# 37766  ...    never pay          soft          good        enough
# 38604  ...    never pay         salty         salty  insufficient
# 41601  ...    never pay         salty         salty  insufficient
# 48361  ...    never pay         salty         salty        enough
# 50232  ...    never pay          soft          good        enough
# 50330  ...    never pay          soft          good        enough
# 50543  ...    never pay         salty         salty  insufficient
# 50694  ...    never pay          soft          good        enough
# 50878  ...    never pay         salty         salty        enough
# 51319  ...    never pay          soft          good  insufficient
# 51672  ...    never pay          soft          good        enough
# 57824  ...      monthly         salty         salty  insufficient
#
#        quantity_group        source   source_type  source_class  \
# 2287           enough  shallow well  shallow well   groundwater
# 7560     insufficient  shallow well  shallow well   groundwater
# 8896           enough  shallow well  shallow well   groundwater
# 10267          enough  shallow well  shallow well   groundwater
# 13570          enough  shallow well  shallow well   groundwater
# 15917    insufficient  shallow well  shallow well   groundwater
# 17442          enough  shallow well  shallow well   groundwater
# 19866          enough  shallow well  shallow well   groundwater
# 24938          enough  shallow well  shallow well   groundwater
# 28701          enough  shallow well  shallow well   groundwater
# 29367          enough  shallow well  shallow well   groundwater
# 29640    insufficient  shallow well  shallow well   groundwater
# 29872          enough  shallow well  shallow well   groundwater
# 30760          enough  shallow well  shallow well   groundwater
# 37766          enough  shallow well  shallow well   groundwater
# 38604    insufficient  shallow well  shallow well   groundwater
# 41601    insufficient  shallow well  shallow well   groundwater
# 48361          enough  shallow well  shallow well   groundwater
# 50232          enough  shallow well  shallow well   groundwater
# 50330          enough  shallow well  shallow well   groundwater
# 50543    insufficient  shallow well  shallow well   groundwater
# 50694          enough  shallow well  shallow well   groundwater
# 50878          enough  shallow well  shallow well   groundwater
# 51319    insufficient  shallow well  shallow well   groundwater
# 51672          enough  shallow well  shallow well   groundwater
# 57824    insufficient  shallow well  shallow well   groundwater
#
#       waterpoint_type waterpoint_type_group
# 2287        hand pump             hand pump
# 7560        hand pump             hand pump
# 8896        hand pump             hand pump
# 10267       hand pump             hand pump
# 13570       hand pump             hand pump
# 15917       hand pump             hand pump
# 17442       hand pump             hand pump
# 19866       hand pump             hand pump
# 24938       hand pump             hand pump
# 28701       hand pump             hand pump
# 29367       hand pump             hand pump
# 29640           other                 other
# 29872       hand pump             hand pump
# 30760       hand pump             hand pump
# 37766       hand pump             hand pump
# 38604       hand pump             hand pump
# 41601       hand pump             hand pump
# 48361       hand pump             hand pump
# 50232           other                 other
# 50330           other                 other
# 50543       hand pump             hand pump
# 50694       hand pump             hand pump
# 50878       hand pump             hand pump
# 51319           other                 other
# 51672       hand pump             hand pump
# 57824       hand pump             hand pump
#
# [26 rows x 40 columns]

# %% [markdown]
# 26 строк с повторяющимися данными. Отсортируем по возрастанию долготы:

# %%
TrainYEARSORT = TrainYEAR.loc[abs(TrainYEAR['longitude'] - 37.3) < 0.1]
TrainYEARSORT.sort_values(by = 'longitude')
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 29367  28980         0.0    2011-03-17                   Abood         486
# 19866   3559         0.0    2011-03-24                   Abood         486
# 50330  36327         0.0    2011-03-24  Government Of Tanzania         499
# 50232  44391         0.0    2011-03-17  Government Of Tanzania         499
# 29640   8451         0.0    2011-03-17                 Germany         496
# 51319  26277         0.0    2011-03-24                 Germany         496
# 48361  31011         0.0    2011-03-24  Government Of Tanzania         503
# 50878  12615         0.0    2011-03-17  Government Of Tanzania         503
# 29872  60190         0.0    2011-03-17                  Tassaf         512
# 13570  21056         0.0    2011-03-24                  Tassaf         512
# 8896   45838         0.0    2011-03-17                Nethalan         519
# 30760  39206         0.0    2011-03-24                Nethalan         519
# 24938  33011         0.0    2011-03-17                  Tassaf         532
# 28701  58162         0.0    2011-03-24                  Tassaf         532
# 17442  54643         0.0    2011-03-24                Nethalan         576
# 37766  18406         0.0    2011-03-16                Nethalan         576
# 51672  14961         0.0    2011-03-16                Nethalan         580
# 50694  42578         0.0    2011-03-23                Nethalan         580
# 38604  64847         0.0    2011-03-16                Nethalan         590
# 7560    8437         0.0    2011-03-23                Nethalan         590
# 2287   42469         0.0    2011-03-24                Nethalan         583
# 10267  49698         0.0    2011-03-17                Nethalan         583
# 41601  62326         0.0    2011-03-24                      Rc         609
# 50543  56848         0.0    2011-03-17                      Rc         609
# 15917  42947      1000.0    2011-03-17                Nethalan         621
# 57824  29698      1000.0    2011-03-24                Nethalan         621
#
#       installer  longitude  latitude                 wpt_name  num_private  \
# 29367   Gwaseco  37.236326 -7.093914                Msikitini            0
# 19866   Gwaseco  37.236326 -7.093914                Msikitini            0
# 50330       DWE  37.250111 -7.104625               Kwa Magera            0
# 50232       DWE  37.250111 -7.104625               Kwa Magera            0
# 29640       RWE  37.252194 -7.103742               Kwa Magera            0
# 51319       RWE  37.252194 -7.103742               Kwa Magera            0
# 48361       DWE  37.269036 -7.104923                 Kwa Beti            0
# 50878       DWE  37.269036 -7.104923                 Kwa Beti            0
# 29872       DWE  37.274352 -7.102004              Kwa Kinenge            0
# 13570       DWE  37.274352 -7.102004              Kwa Kinenge            0
# 8896        RWE  37.281357 -7.095131             Kwa Batolome            0
# 30760       RWE  37.281357 -7.095131             Kwa Batolome            0
# 24938       DWE  37.297680 -7.078081            Kwa Gungulima            0
# 28701       DWE  37.297680 -7.078081            Kwa Gungulima            0
# 17442  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka            0
# 37766  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka            0
# 51672       DWE  37.318911 -7.177155             Kwa Kisuguru            0
# 50694       DWE  37.318911 -7.177155             Kwa Kisuguru            0
# 38604       RWE  37.328905 -7.175174          Kwa Said Mlinda            0
# 7560        RWE  37.328905 -7.175174          Kwa Said Mlinda            0
# 2287        RWE  37.339811 -7.065373                  Ofisini            0
# 10267       RWE  37.339811 -7.065373                  Ofisini            0
# 41601        RC  37.374017 -7.056923                 Kanisani            0
# 50543        RC  37.374017 -7.056923                 Kanisani            0
# 15917       RWE  37.375717 -7.056372                Kwa Yusta            0
# 57824       RWE  37.375717 -7.056372                Kwa Yusta            0
#
#        ... payment_type water_quality quality_group      quantity  \
# 29367  ...    never pay          soft          good        enough
# 19866  ...    never pay          soft          good        enough
# 50330  ...    never pay          soft          good        enough
# 50232  ...    never pay          soft          good        enough
# 29640  ...    never pay          soft          good  insufficient
# 51319  ...    never pay          soft          good  insufficient
# 48361  ...    never pay         salty         salty        enough
# 50878  ...    never pay         salty         salty        enough
# 29872  ...    never pay         salty         salty        enough
# 13570  ...    never pay         salty         salty        enough
# 8896   ...    never pay          soft          good        enough
# 30760  ...    never pay          soft          good        enough
# 24938  ...    never pay          soft          good        enough
# 28701  ...    never pay          soft          good        enough
# 17442  ...    never pay          soft          good        enough
# 37766  ...    never pay          soft          good        enough
# 51672  ...    never pay          soft          good        enough
# 50694  ...    never pay          soft          good        enough
# 38604  ...    never pay         salty         salty  insufficient
# 7560   ...    never pay         salty         salty  insufficient
# 2287   ...    never pay          soft          good        enough
# 10267  ...    never pay          soft          good        enough
# 41601  ...    never pay         salty         salty  insufficient
# 50543  ...    never pay         salty         salty  insufficient
# 15917  ...      monthly         salty         salty  insufficient
# 57824  ...      monthly         salty         salty  insufficient
#
#        quantity_group        source   source_type  source_class  \
# 29367          enough  shallow well  shallow well   groundwater
# 19866          enough  shallow well  shallow well   groundwater
# 50330          enough  shallow well  shallow well   groundwater
# 50232          enough  shallow well  shallow well   groundwater
# 29640    insufficient  shallow well  shallow well   groundwater
# 51319    insufficient  shallow well  shallow well   groundwater
# 48361          enough  shallow well  shallow well   groundwater
# 50878          enough  shallow well  shallow well   groundwater
# 29872          enough  shallow well  shallow well   groundwater
# 13570          enough  shallow well  shallow well   groundwater
# 8896           enough  shallow well  shallow well   groundwater
# 30760          enough  shallow well  shallow well   groundwater
# 24938          enough  shallow well  shallow well   groundwater
# 28701          enough  shallow well  shallow well   groundwater
# 17442          enough  shallow well  shallow well   groundwater
# 37766          enough  shallow well  shallow well   groundwater
# 51672          enough  shallow well  shallow well   groundwater
# 50694          enough  shallow well  shallow well   groundwater
# 38604    insufficient  shallow well  shallow well   groundwater
# 7560     insufficient  shallow well  shallow well   groundwater
# 2287           enough  shallow well  shallow well   groundwater
# 10267          enough  shallow well  shallow well   groundwater
# 41601    insufficient  shallow well  shallow well   groundwater
# 50543    insufficient  shallow well  shallow well   groundwater
# 15917    insufficient  shallow well  shallow well   groundwater
# 57824    insufficient  shallow well  shallow well   groundwater
#
#       waterpoint_type waterpoint_type_group
# 29367       hand pump             hand pump
# 19866       hand pump             hand pump
# 50330           other                 other
# 50232           other                 other
# 29640           other                 other
# 51319           other                 other
# 48361       hand pump             hand pump
# 50878       hand pump             hand pump
# 29872       hand pump             hand pump
# 13570       hand pump             hand pump
# 8896        hand pump             hand pump
# 30760       hand pump             hand pump
# 24938       hand pump             hand pump
# 28701       hand pump             hand pump
# 17442       hand pump             hand pump
# 37766       hand pump             hand pump
# 51672       hand pump             hand pump
# 50694       hand pump             hand pump
# 38604       hand pump             hand pump
# 7560        hand pump             hand pump
# 2287        hand pump             hand pump
# 10267       hand pump             hand pump
# 41601       hand pump             hand pump
# 50543       hand pump             hand pump
# 15917       hand pump             hand pump
# 57824       hand pump             hand pump
#
# [26 rows x 40 columns]

# %%
Видим следующее: 
    1. У каждой из дублирующихся водокачек есть по 2 записи
    2. Даты первых и вторых записей у большинства из них совпадают
    3. Даты записей всех дублирующихся водокачек близки друг к другу
    
Делаем предположения:
    1. Сбором данных занимались две несообщённые группы - в таком случае можно исключить данные из выборки при условии
        неверности нижеследующего пункта.
    2. Записи сделаны по причине изменения состояния водокачек - проверяем.

# %%
Извлечём из данных о состоянии водокачек две случайные записи под номерами, 
под которыми они дублируются в данных об их характеристиках:

# %%
#NewTrain = pd.merge(TrainYEARSORT, TrainingY, on = 'id','status_group', how = 'right')
#NewTrain

val = TrainYEARSORT
val1 = TrainingY
val1 = val1.merge(val, on = 'id', how = 'right')
val1.sort_values(by = 'latitude')
# Out:
#        id    status_group  amount_tsh date_recorded                  funder  \
# 6   54643      functional         0.0    2011-03-24                Nethalan
# 14  18406      functional         0.0    2011-03-16                Nethalan
# 21  42578      functional         0.0    2011-03-23                Nethalan
# 24  14961      functional         0.0    2011-03-16                Nethalan
# 1    8437  non functional         0.0    2011-03-23                Nethalan
# 15  64847  non functional         0.0    2011-03-16                Nethalan
# 17  31011  non functional         0.0    2011-03-24  Government Of Tanzania
# 22  12615  non functional         0.0    2011-03-17  Government Of Tanzania
# 19  36327  non functional         0.0    2011-03-24  Government Of Tanzania
# 18  44391  non functional         0.0    2011-03-17  Government Of Tanzania
# 23  26277  non functional         0.0    2011-03-24                 Germany
# 11   8451  non functional         0.0    2011-03-17                 Germany
# 12  60190      functional         0.0    2011-03-17                  Tassaf
# 4   21056      functional         0.0    2011-03-24                  Tassaf
# 13  39206      functional         0.0    2011-03-24                Nethalan
# 2   45838      functional         0.0    2011-03-17                Nethalan
# 7    3559  non functional         0.0    2011-03-24                   Abood
# 10  28980  non functional         0.0    2011-03-17                   Abood
# 8   33011      functional         0.0    2011-03-17                  Tassaf
# 9   58162      functional         0.0    2011-03-24                  Tassaf
# 0   42469      functional         0.0    2011-03-24                Nethalan
# 3   49698      functional         0.0    2011-03-17                Nethalan
# 16  62326  non functional         0.0    2011-03-24                      Rc
# 20  56848  non functional         0.0    2011-03-17                      Rc
# 5   42947      functional      1000.0    2011-03-17                Nethalan
# 25  29698      functional      1000.0    2011-03-24                Nethalan
#
#     gps_height installer  longitude  latitude                 wpt_name  ...  \
# 6          576  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka  ...
# 14         576  Hanja Lt  37.314250 -7.177203  Shule Yamsingi Maharaka  ...
# 21         580       DWE  37.318911 -7.177155             Kwa Kisuguru  ...
# 24         580       DWE  37.318911 -7.177155             Kwa Kisuguru  ...
# 1          590       RWE  37.328905 -7.175174          Kwa Said Mlinda  ...
# 15         590       RWE  37.328905 -7.175174          Kwa Said Mlinda  ...
# 17         503       DWE  37.269036 -7.104923                 Kwa Beti  ...
# 22         503       DWE  37.269036 -7.104923                 Kwa Beti  ...
# 19         499       DWE  37.250111 -7.104625               Kwa Magera  ...
# 18         499       DWE  37.250111 -7.104625               Kwa Magera  ...
# 23         496       RWE  37.252194 -7.103742               Kwa Magera  ...
# 11         496       RWE  37.252194 -7.103742               Kwa Magera  ...
# 12         512       DWE  37.274352 -7.102004              Kwa Kinenge  ...
# 4          512       DWE  37.274352 -7.102004              Kwa Kinenge  ...
# 13         519       RWE  37.281357 -7.095131             Kwa Batolome  ...
# 2          519       RWE  37.281357 -7.095131             Kwa Batolome  ...
# 7          486   Gwaseco  37.236326 -7.093914                Msikitini  ...
# 10         486   Gwaseco  37.236326 -7.093914                Msikitini  ...
# 8          532       DWE  37.297680 -7.078081            Kwa Gungulima  ...
# 9          532       DWE  37.297680 -7.078081            Kwa Gungulima  ...
# 0          583       RWE  37.339811 -7.065373                  Ofisini  ...
# 3          583       RWE  37.339811 -7.065373                  Ofisini  ...
# 16         609        RC  37.374017 -7.056923                 Kanisani  ...
# 20         609        RC  37.374017 -7.056923                 Kanisani  ...
# 5          621       RWE  37.375717 -7.056372                Kwa Yusta  ...
# 25         621       RWE  37.375717 -7.056372                Kwa Yusta  ...
#
#     payment_type water_quality quality_group      quantity  quantity_group  \
# 6      never pay          soft          good        enough          enough
# 14     never pay          soft          good        enough          enough
# 21     never pay          soft          good        enough          enough
# 24     never pay          soft          good        enough          enough
# 1      never pay         salty         salty  insufficient    insufficient
# 15     never pay         salty         salty  insufficient    insufficient
# 17     never pay         salty         salty        enough          enough
# 22     never pay         salty         salty        enough          enough
# 19     never pay          soft          good        enough          enough
# 18     never pay          soft          good        enough          enough
# 23     never pay          soft          good  insufficient    insufficient
# 11     never pay          soft          good  insufficient    insufficient
# 12     never pay         salty         salty        enough          enough
# 4      never pay         salty         salty        enough          enough
# 13     never pay          soft          good        enough          enough
# 2      never pay          soft          good        enough          enough
# 7      never pay          soft          good        enough          enough
# 10     never pay          soft          good        enough          enough
# 8      never pay          soft          good        enough          enough
# 9      never pay          soft          good        enough          enough
# 0      never pay          soft          good        enough          enough
# 3      never pay          soft          good        enough          enough
# 16     never pay         salty         salty  insufficient    insufficient
# 20     never pay         salty         salty  insufficient    insufficient
# 5        monthly         salty         salty  insufficient    insufficient
# 25       monthly         salty         salty  insufficient    insufficient
#
#           source   source_type source_class  waterpoint_type  \
# 6   shallow well  shallow well  groundwater        hand pump
# 14  shallow well  shallow well  groundwater        hand pump
# 21  shallow well  shallow well  groundwater        hand pump
# 24  shallow well  shallow well  groundwater        hand pump
# 1   shallow well  shallow well  groundwater        hand pump
# 15  shallow well  shallow well  groundwater        hand pump
# 17  shallow well  shallow well  groundwater        hand pump
# 22  shallow well  shallow well  groundwater        hand pump
# 19  shallow well  shallow well  groundwater            other
# 18  shallow well  shallow well  groundwater            other
# 23  shallow well  shallow well  groundwater            other
# 11  shallow well  shallow well  groundwater            other
# 12  shallow well  shallow well  groundwater        hand pump
# 4   shallow well  shallow well  groundwater        hand pump
# 13  shallow well  shallow well  groundwater        hand pump
# 2   shallow well  shallow well  groundwater        hand pump
# 7   shallow well  shallow well  groundwater        hand pump
# 10  shallow well  shallow well  groundwater        hand pump
# 8   shallow well  shallow well  groundwater        hand pump
# 9   shallow well  shallow well  groundwater        hand pump
# 0   shallow well  shallow well  groundwater        hand pump
# 3   shallow well  shallow well  groundwater        hand pump
# 16  shallow well  shallow well  groundwater        hand pump
# 20  shallow well  shallow well  groundwater        hand pump
# 5   shallow well  shallow well  groundwater        hand pump
# 25  shallow well  shallow well  groundwater        hand pump
#
#    waterpoint_type_group
# 6              hand pump
# 14             hand pump
# 21             hand pump
# 24             hand pump
# 1              hand pump
# 15             hand pump
# 17             hand pump
# 22             hand pump
# 19                 other
# 18                 other
# 23                 other
# 11                 other
# 12             hand pump
# 4              hand pump
# 13             hand pump
# 2              hand pump
# 7              hand pump
# 10             hand pump
# 8              hand pump
# 9              hand pump
# 0              hand pump
# 3              hand pump
# 16             hand pump
# 20             hand pump
# 5              hand pump
# 25             hand pump
#
# [26 rows x 41 columns]

# %% [markdown]
# Случайная проверка показала, что утверждение №2 неверно. Делаем вывод, что дублирующиеся данные скорее всего не дают никакой полезной информации, поэтому их можн (и даже нужно) удалить. Однако есть проблема: не во всех строчках заполнены все поля. Нам необходимо либо их дозаполнить, либо удалить записи по тем столбцам, которые заполнены у всех.

# %% [markdown]
# ## Дата ввода данных
# Оценим разброс дат ввода данных. Если ввод был совершён слишком давно или слишком недавно относительно большинства дат, то такая дата может негативно сказаться на точности прогноза, т.к. если, например, запись была совершена за 40
